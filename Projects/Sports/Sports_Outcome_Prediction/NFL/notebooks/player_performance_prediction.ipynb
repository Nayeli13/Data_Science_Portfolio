# %% [markdown]
# <h3>Importar Librerias</h3>

# %%
#Instalacin de Librerias

# !pip install tabulate

#Llamado de Librerias
import numpy as  np
import pandas as pd
import sklearn as skl
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import matplotlib.image as mpimg

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, precision_score, make_scorer, roc_curve, auc
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score


import warnings
warnings.filterwarnings('ignore')
# Out:
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# <h3>Entendimiento de los Datos Iniciales</h3>

# %%
quarterback = pd.read_csv("../data/Game_Logs_Quarterback.csv")
quarterback.head()
# Out:
#                 Player Id              Name Position  Year          Season  \
# 0  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 1  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 2  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 3  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 4      billdemory/2512778      Demory, Bill      NaN  1974  Regular Season
#
#    Week Game Date Home or Away Opponent Outcome  ... Ints  Sacks  \
# 0     1     08/11         Home      CHI       L  ...   --     --
# 1     2     08/18         Away      ARI       W  ...    0      0
# 2     3     08/25         Home      DAL       W  ...   --     --
# 3     4     08/30         Away       TB       L  ...    1      2
# 4     1     09/15         Away       KC       L  ...   --     --
#
#   Sacked Yards Lost Passer Rating Rushing Attempts Rushing Yards  \
# ...

# %%
runningback = pd.read_csv("../data/Game_Logs_Runningback.csv")
runningback.head()
# Out:
#              Player Id           Name Position  Year          Season  Week  \
# 0  bobbyfowler/2514295  Fowler, Bobby      NaN  1985  Regular Season     7
# 1  bobbyfowler/2514295  Fowler, Bobby      NaN  1985  Regular Season     8
# 2  bobbyfowler/2514295  Fowler, Bobby      NaN  1985  Regular Season     9
# 3  bobbyfowler/2514295  Fowler, Bobby      NaN  1985  Regular Season    10
# 4  bobbyfowler/2514295  Fowler, Bobby      NaN  1985  Regular Season    11
#
#   Game Date Home or Away Opponent Outcome  ... Yards Per Carry  \
# 0     10/20         Away      ATL       L  ...              --
# 1     10/27         Home      NYG       L  ...              --
# 2     11/03         Away      RAM       L  ...              --
# 3     11/10         Home      SEA       L  ...              --
# 4     11/17         Away       GB       L  ...             1.0
#
#    Longest Rushing Run Rushing TDs Receptions Receiving Yards  \
# 0                   --          --         --              --
# ...

# %%
wide_Receiver = pd.read_csv("../data/Game_Logs_Wide_Receiver_and_Tight_End.csv")
wide_Receiver.head()
# Out:
#              Player Id           Name Position  Year          Season  Week  \
# 0  floydraglin/2523695  Raglin, Floyd      NaN  1987  Regular Season     3
# 1  floydraglin/2523695  Raglin, Floyd      NaN  1987  Regular Season     4
# 2     joeadams/2532782     Adams, Joe      NaN  2014       Preseason     1
# 3     joeadams/2532782     Adams, Joe      NaN  2014       Preseason     2
# 4     joeadams/2532782     Adams, Joe      NaN  2014       Preseason     3
#
#   Game Date Home or Away Opponent Outcome  ... Yards Per Reception  \
# 0     10/04         Away      SEA       L  ...                  --
# 1     10/11         Home       KC       W  ...                  --
# 2     08/09         Away      ARI       L  ...                  --
# 3     08/16         Home      ATL       W  ...                  --
# 4     08/23         Away      DEN       W  ...                  --
#
#    Longest Reception Receiving TDs Rushing Attempts Rushing Yards  \
# ...

# %%
defensive_Line = pd.read_csv("../data/Game_Logs_Defensive_Lineman.csv")
defensive_Line.head()
# Out:
#             Player Id          Name Position  Year          Season  Week  \
# 0  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     1
# 1  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     2
# 2  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     3
# 3  l.t.walton/2552444  Walton, L.T.       DE  2016       Preseason     4
# 4  l.t.walton/2552444  Walton, L.T.       DE  2016  Regular Season     1
#
#   Game Date Home or Away Opponent Outcome  ... Assisted Tackles  Sacks  \
# 0     08/12         Home      DET       L  ...                0    0.0
# 1     08/18         Home      PHI       L  ...               --     --
# 2     08/26         Away       NO       W  ...               --     --
# 3     09/01         Away      CAR       L  ...                3    0.0
# 4     09/12         Away      WAS       W  ...               --     --
#
#   Safties Passes Defended Ints Int Yards Yards Per Int Longest Int Return  \
# ...

# %%
offensive_Line = pd.read_csv("../data/Game_Logs_Offensive_Line.csv")
offensive_Line.head()
# Out:
#             Player Id          Name Position  Year     Season  Week Game Date  \
# 0    jeffnady/2541732    Nady, Jeff      NaN  2013  Preseason     2     08/15
# 1  chrisriley/2530729  Riley, Chris      NaN  2011  Preseason     1     08/12
# 2  chrisriley/2530729  Riley, Chris      NaN  2011  Preseason     2     08/21
# 3  chrisriley/2530729  Riley, Chris      NaN  2011  Preseason     3     08/25
# 4  chrisriley/2530729  Riley, Chris      NaN  2011  Preseason     4     09/01
#
#   Home or Away Opponent Outcome     Score  Games Played Games Started
# 0         Away      BAL       L  23 to 27             0             0
# 1         Away      DET       L   3 to 34             1             0
# 2         Away      NYJ       L   7 to 27             1             0
# 3         Home      CAR       W  24 to 13             1             0
# 4         Home      IND       L  13 to 17             1             0
