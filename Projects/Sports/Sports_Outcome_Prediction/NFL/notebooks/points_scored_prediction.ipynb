# %% [markdown]
# <h3>Importar Librerias</h3>

# %%
#Instalacin de Librerias

# !pip install tabulate

#Llamado de Librerias
import numpy as  np
import pandas as pd
import sklearn as skl
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import matplotlib.image as mpimg

from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, precision_score, make_scorer, roc_curve, auc
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score


import warnings
warnings.filterwarnings('ignore')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <h3>Entendimiento de los Datos Iniciales</h3>

# %%
Stats_Defensive = pd.read_csv("../data/Career_Stats_Defensive.csv")
Stats_Defensive.head()
# Out:
#             Player Id            Name Position  Year               Team  \
# 0  quinnjohnson/79593  Johnson, Quinn      NaN  2013   Tennessee Titans
# 1  quinnjohnson/79593  Johnson, Quinn      NaN  2012   Tennessee Titans
# 2  quinnjohnson/79593  Johnson, Quinn      NaN  2011   Tennessee Titans
# 3  quinnjohnson/79593  Johnson, Quinn      NaN  2011     Denver Broncos
# 4  quinnjohnson/79593  Johnson, Quinn      NaN  2010  Green Bay Packers
#
#    Games Played Total Tackles Solo Tackles Assisted Tackles Sacks Safties  \
# 0             4             0           --               --    --      --
# 1            16             1            1                0   0.0      --
# 2             4             0           --               --    --      --
# 3             0             0           --               --    --      --
# 4            11             4            4                0   0.0      --
#
#   Passes Defended Ints Ints for TDs Int Yards  Yards Per Int  \
# ...

# %%
Stats_Punting = pd.read_csv("../data/Career_Stats_Punting.csv")
Stats_Punting.head()
# Out:
#             Player Id          Name Position  Year                 Team  \
# 0   davebaker/2508869   Baker, Dave      NaN  1961  San Francisco 49ers
# 1   davebaker/2508869   Baker, Dave      NaN  1960  San Francisco 49ers
# 2   davebaker/2508869   Baker, Dave      NaN  1959  San Francisco 49ers
# 3  jasonbaker/2504395  Baker, Jason      NaN  2011    Carolina Panthers
# 4  jasonbaker/2504395  Baker, Jason      NaN  2010    Carolina Panthers
#
#    Games Played Punts Gross Punting Yards Net Punting Yards Longest Punt  ...  \
# 0            14    --                  --                --           --  ...
# 1            12     3                 143                --           --  ...
# 2            12    --                  --                --           --  ...
# 3            16    66               2,819             2,253           56  ...
# 4            16    95               4,097             3,469           60  ...
#
# ...

# %%
Stats_Punting = pd.read_csv("../data/Career_Stats_Field_Goal_Kickers.csv")
Stats_Punting.head()
